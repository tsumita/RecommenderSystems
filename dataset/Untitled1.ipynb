# %%
print("a")
# Out:
# a

# %%
import pandas as pd
df= pd.read_csv("/home/tsumita/tsumita/RecommenderSystems/dataset/del_10per/matrix_trn.csv")

# %%
fill_df = df.fillna(0)
M = fill_df.values

# %%
delete_M = np.delete(M, [0], 1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-7b09c6909a8f> in <module>()
# ----> 1 delete_M = np.delete(M, [0], 1)
#
# NameError: name 'np' is not defined

# %%
import numpy as np

# %%
delete_M = np.delete(M, [0], 1)

# %%
for i in range(8000):
    for l in range(10000):
        delete_M[i][l] = delete_M[i][l]*100

# %%
n, m = delete_M.shape
W = np.random.rand(n, 100)
H = np.random.rand(100, m)
mask_M = (delete_M > 0)

# %%
def update(Y, W, H, M):
    W = W * np.dot(Y * M, H.T) / np.dot(np.dot(W, H) * M, H.T)
    H = H * np.dot(W.T, Y * M) / np.dot(W.T, np.dot(W, H) * M)
    print(ok)
    return W, H

# %%
for _ in range(1):
    W, H = update(delete_M, W, H, mask_M)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-22f09042e590> in <module>()
#       1 for _ in range(1):
# ----> 2     W, H = update(delete_M, W, H, mask_M)
#
# <ipython-input-9-72387d9bea4d> in update(Y, W, H, M)
#       2     W = W * np.dot(Y * M, H.T) / np.dot(np.dot(W, H) * M, H.T)
#       3     H = H * np.dot(W.T, Y * M) / np.dot(W.T, np.dot(W, H) * M)
# ----> 4     print(ok)
#       5     return W, H
#
# NameError: name 'ok' is not defined

# %%
def update(Y, W, H, M):
    W = W * np.dot(Y * M, H.T) / np.dot(np.dot(W, H) * M, H.T)
    H = H * np.dot(W.T, Y * M) / np.dot(W.T, np.dot(W, H) * M)
    print("ok")
    return W, H

# %%
def update(Y, W, H, M):
    W = W * np.dot(Y * M, H.T) / np.dot(np.dot(W, H) * M, H.T)
    print("ok")
    H = H * np.dot(W.T, Y * M) / np.dot(W.T, np.dot(W, H) * M)
    print("ok")
    return W, H

# %%
for _ in range(1):
    W, H = update(delete_M, W, H, mask_M)
# Out:
# ok
# ok

# %%
pd.DataFrame(W @ H, index=users, columns=items)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-cb89c7011263> in <module>()
# ----> 1 pd.DataFrame(W @ H, index=users, columns=items)
#
# TypeError: Object arrays are not currently supported

# %%
pd.DataFrame(W @ H, index=users)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-f5d7b7de5377> in <module>()
# ----> 1 pd.DataFrame(W @ H, index=users)
#
# TypeError: Object arrays are not currently supported

# %%
pd.DataFrame(W @ H)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-005da1f7f23a> in <module>()
# ----> 1 pd.DataFrame(W @ H)
#
# TypeError: Object arrays are not currently supported

# %%
pd.DataFrame(W.dot(H), index=users, columns=items)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-1fe1e652ba35> in <module>()
# ----> 1 pd.DataFrame(W * H, index=users, columns=items)
#
# ValueError: operands could not be broadcast together with shapes (8000,100) (100,10000)

# %%
pd.DataFrame(W.dot(H), index=users, columns=items)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-f0f12ee9fb28> in <module>()
# ----> 1 pd.DataFrame(W.dot(H), index=users, columns=items)
#
# NameError: name 'users' is not defined

# %%
pd.DataFrame(W.dot(H))
# Out:
#          0        1        2        3        4        5        6        7     \
# 0     61.5647  46.2895  51.4371  59.6661   67.039  63.0514  60.4658  53.4648
# 1     62.0886  48.9261  51.8202  60.6045  67.3973  63.5083  69.8649  54.7475
# 2     61.3383   47.396  52.6417  53.6214  65.8005  61.5412  63.0246  54.6401
# 3     60.6171  45.2802  49.5671  58.9268  65.0665  63.3358  61.0885  51.9153
# 4     62.8873  43.1899  52.5341   57.878    67.67  62.6555  65.1613  53.7237
# 5     61.8963  48.2704  50.9606  57.6741   69.856  63.3237  62.7978  52.3696
# 6     62.9072  45.4605  49.4945  57.4862  68.6508  60.8448  64.5781  50.9744
# 7     59.6548  42.8563  44.8479  60.0686  66.6963  64.2411  62.1143  51.8197
# 8     61.5715  46.6803   47.047  58.0901  69.1979  64.8697  63.5701  49.2676
# 9     66.1401  49.1347   53.583  61.0805  72.3947   68.748  67.9663  58.2835
# 10    66.7528  47.1047  50.1704  57.8815  67.9676  64.1251  60.0719  53.4927
# ...

# %%
for _ in range(2):
    W, H = update(delete_M, W, H, mask_M)
# Out:
# ok
# ok
# ok
# ok

# %%
pd.DataFrame(W.dot(H))
# Out:
#          0        1        2        3        4        5        6        7     \
# 0     61.4379  46.2157  51.3135  59.5425  66.9245  62.9347  60.3739  53.4053
# 1     62.0205  48.8848  51.7468  60.5499  67.3363  63.4692  69.7254  54.7121
# 2     61.3383   47.344  52.6044  53.6264  65.8436  61.5802  63.0238  54.6293
# 3     60.6824  45.3648  49.6695  59.0269  65.1867  63.4442  61.2296  52.0034
# 4     63.0132  43.3217  52.6209  58.0238  67.8056  62.8107  65.3015  53.8343
# 5     61.9966  48.3118  51.0423   57.751  69.9387  63.4221  62.9048  52.4555
# 6     62.7744  45.3989   49.373  57.3755  68.4964  60.7211  64.4083  50.8699
# 7     59.8483  43.0019  45.0232  60.2483  66.9035   64.391  62.2987  51.9879
# 8     61.4042  46.5341  46.9294  57.9352  68.9441  64.6789  63.3878  49.1827
# 9     66.0853  49.1194  53.5565  61.0559  72.3227  68.6928  67.9328  58.2293
# 10    66.8573  47.1994  50.2872  57.9931  68.1117  64.2862  60.2383  53.6054
# ...

# %%
for _ in range(2):
    W, H = update(delete_M, W, H, mask_M)
