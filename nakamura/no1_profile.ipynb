# %%
import pandas as pd

# %%
df_matrix = pd.read_csv("../dataset/origin_matrix.csv", index_col=0)

# %%
df_matrix
# Out:
#              item_0    item_1    item_2    item_3    item_4    item_5  \
# user_0     0.597859  0.544633  0.553456  0.692309  0.773937  0.740925
# user_1     0.631693  0.494963  0.506338  0.540617  0.623003  0.608106
# user_2     0.470106  0.444696  0.548824  0.465589  0.723931  0.564409
# user_3     0.484086  0.242101  0.287123  0.628113  0.697996  0.708477
# user_4     0.662280  0.596565  0.550002  0.724620  0.607163  0.583914
# user_5     0.817015  0.581271  0.542586  0.609495  0.576781  0.694712
# user_6     0.907556  0.514386  0.544031  0.730462  0.644346  0.431919
# user_7     0.661530  0.676393  0.566224  0.563679  0.675527  0.480091
# user_8     0.758987  0.444895  0.608527  0.542596  0.669047  0.575294
# user_9     0.663751  0.465374  0.517178  0.503074  0.647028  0.817336
# user_10    0.656383  0.688607  0.528382  0.609849  0.761554  0.469937
# user_11    0.600482  0.347867  0.528633  0.577821  0.812808  0.685758
# ...
